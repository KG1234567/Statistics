# %% [markdown]
# ## Statistics - 3
#
# Correlation

# %%
import numpy as np

# %%
x = [1,2,3]
y = [30,40,50]

# %%
print(np.corrcoef(x,y))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %% [markdown]
# Output format of corrcoef

# %%
""" [top-left [x,x], top-right [x,y]]
bottom-left [y,x], bottom-right [y,y]] """
# Out:
# ' [top-left [x,x], top-right [x,y]]\nbottom-left [y,x], bottom-right [y,y]] '

# %% [markdown]
# ### Correlation using Titanic Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"
df = pd.read_csv(url)

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
numeric_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='str')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
corr_matrix = numeric_df.corr()

# %%
corr_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## PDF

# %%
import numpy as np

# %%
bins = [150, 155, 160, 165, 170, 175, 180]

# %%
pdf_values = [0.01,0,0.03,0.06,0.06,0.04]

# %%
plt.bar(bins[:-1], pdf_values, width=5, edgecolor='black', alpha=0.7)
plt.title("PDF of Heights")
plt.xlabel("Height (cm)")
plt.ylabel("Probability Density")
plt.show()
