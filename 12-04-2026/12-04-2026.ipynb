# %% [markdown]
# ## Statistics - 4

# %%
from scipy.stats import bernoulli

# %%
p = 0.6

# %%
print(bernoulli.pmf(1, p))  # Probability of success (1)
# Out:
# 0.6

# %%
print(bernoulli.pmf(0, p))  # Probability of failure (0)
# Out:
# 0.4000000000000001
